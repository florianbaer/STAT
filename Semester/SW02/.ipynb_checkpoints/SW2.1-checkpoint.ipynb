# %%
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt


data = Series([4.2, 2.3, 5.6, 4.5, 4.8, 3.9, 5.9, 2.4, 5.9, 6, 4, 3.7, 5, 5.2, 4.5, 3.6, 5, 6, 2.8, 3.3, 5.5, 4.2, 4.9, 5.1])

# %%
data.sort_values()

print(data.mean())
print(data.median())
data2 = data.copy()
data2.iloc[1] = -123213
data2.iloc[7] = -123123
data2.iloc[18] = -123123
# nach bearbeiten
print(data2.mean())
print(data2.median())
# Out:
# 4.5125
# 4.65
# -15389.924999999997
# 4.65

# %%
fig, ax = plt.subplots()
data.plot(kind="hist", edgecolor="black")
data.plot(x='year', y='unemployment', ax=ax, legend=False)
plt.title("Histogramm von Methode A")
plt.xlabel("methodeA")
plt.ylabel("Haeufigkeit")
plt.show()

# %%
data2.plot(kind="hist", edgecolor="black")
plt.title("Histogramm von data")
plt.xlabel("data")
plt.ylabel("Haeufigkeit")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-52c200fa1f82> in <module>
# ----> 1 data2.subplot(kind="hist", edgecolor="black")
#       2 plt.title("Histogramm von data")
#       3 plt.xlabel("data")
#       4 plt.ylabel("Haeufigkeit")
#       5 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'subplot'
