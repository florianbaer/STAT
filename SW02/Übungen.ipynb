# %% [markdown]
# # Aufgabe 2.1

# %%
from pandas import Series
import pandas as pd

data = Series([4.2, 2.3, 5.6, 4.5, 4.8, 3.9, 5.9, 2.4, 5.9, 6, 4, 3.7, 5, 5.2, 4.5, 3.6, 5, 6, 2.8, 3.3, 5.5, 4.2, 4.9, 5.1])
dataModified = data.copy()
#mittelwert
print(data.median())

# ändern
dataModified[23] = 43434
dataModified[2] = 234243
dataModified[8] = 234243

print(dataModified.median())
# Out:
# 4.65
# 4.65

# %%
import matplotlib.pyplot as plt

plt.subplot(2,2,1)
data.plot(kind="hist", edgecolor="black")
plt.title("Histogramm von Methode A")
plt.xlabel("methodeA")
plt.ylabel("Haeufigkeit")

plt.subplot(2,2,2)
dataModified.plot(kind="hist", edgecolor="black", color="green")
plt.title("Histogramm von Methode A")
plt.xlabel("methodeA")
plt.ylabel("Haeufigkeit")

plt.subplot(2,2,3)
data.plot(kind="box", title="box1")

plt.subplot(2,2,4)
dataModified.plot(kind="box", title="box2")

# %% [markdown]
# # Aufgabe 2.2

# %%
from pandas import Series
import pandas as pd
schlamm = pd.read_csv("klaerschlamm.dat", sep=" ", index_col=0)
schlamm = schlamm.drop("Labor",1)
schlamm.head()
# Out:
#    Pr1  Pr2  Pr3  Pr4  Pr5  Pr6  Pr7  Pr8  Pr9
# 1  233  491  428  376  200  364  474  444  351
# 2  253  530  453  389  191  402  495  453  371
# 3  240  530  460  390  200  390  480  440  350
# 4  243  518  456  389  186  385  483  459  369
# 5  244  521  446  392  193  385  481  451  357

# %%
import matplotlib.pyplot as plt

for number in range(1,10):
    # print(schlamm.iloc[:,number-1])
    plt.subplot(1,10,number)
    schlamm.iloc[:,number-1].plot(kind="box", title=number)

# %%
schlamm.describe()
# Out:
#               Pr1         Pr2         Pr3         Pr4         Pr5         Pr6  \
# count   21.000000   21.000000   21.000000   21.000000   21.000000   21.000000
# mean   246.142857  511.428571  443.428571  389.238095  188.238095  394.857143
# std     18.210672   76.962050   34.156363   56.642656   16.866845   56.642110
# min    216.000000  268.000000  378.000000  223.000000  157.000000  337.000000
# 25%    239.000000  491.000000  422.000000  373.000000  178.000000  366.000000
# 50%    244.000000  521.000000  446.000000  390.000000  188.000000  385.000000
# 75%    257.000000  530.000000  459.000000  405.000000  200.000000  393.000000
# max    296.000000  732.000000  548.000000  562.000000  221.000000  557.000000
#
#               Pr7         Pr8         Pr9
# count   21.000000   21.000000   21.000000
# mean   465.523810  449.952381  388.904762
# std     91.361162   57.069673  104.159927
# min    110.000000  323.000000  319.000000
# 25%    456.000000  423.000000  350.000000
# ...

# %% [markdown]
# Bei 1,4,5,6,9

# %%
# Messfehler eines Labors
schlamm_centered = schlamm - schlamm.median()
schlamm_centered.T.plot(kind="box")

# %% [markdown]
# # Aufgabe 2.4

# %%
hubble = pd.read_csv("hubble.txt", sep=" ")
print(hubble)
# Out:
#     distance  recession.velocity
# 0      0.032                 170
# 1      0.034                 290
# 2      0.214                -130
# 3      0.263                 -70
# 4      0.275                -185
# 5      0.275                -220
# 6      0.450                 200
# 7      0.500                 290
# 8      0.500                 270
# 9      0.630                 200
# 10     0.800                 300
# 11     0.900                 -30
# 12     0.900                 650
# 13     0.900                 150
# 14     0.900                 500
# 15     1.000                 920
# 16     1.100                 450
# 17     1.100                 500
# 18     1.400                 500
# 19     1.700                 960
# 20     2.000                 500
# 21     2.000                 850
# 22     2.000                 800
# 23     2.000                1090

# %%
hubble.plot.scatter(x='distance',y='recession.velocity', deg=1)

# %%
import numpy as np
hubble.plot(kind="scatter", x="recession.velocity", y="distance")
b, a = np.polyfit(x=hubble["recession.velocity"], y=hubble["distance"], deg=1)
x = np.linspace(hubble["recession.velocity"].min() ,hubble["recession.velocity"].max())
plt.plot(x, a+b*x, c="orange")
plt.show()

# %%
hubble.corr()
# Out:
#                     distance  recession.velocity
# distance            1.000000            0.789639
# recession.velocity  0.789639            1.000000

# %% [markdown]
# Mit 0.789639 ist der korrelationskoeffizient recht hoch und es scheint einen grossen zusammenhang der beiden Datensätze zu geben.

# %% [markdown]
# # Aufgabe 2.5

# %%
income = pd.read_csv("income.dat", sep=" ")
income.plot(kind="scatter", y="Income2005", x="Educ")

# %%
income = pd.read_csv("income.dat", sep=" ")
income.plot(kind="scatter", y="Income2005", x="AFQT")

# %%
income.plot(kind="scatter", y="Income2005", x="Educ")
x = np.linspace(income["Educ"].min() ,income["Educ"].max())
b, a = np.polyfit(x=income["Educ"], y=income["Income2005"], deg=1)
plt.plot(x, a+b*x, c="orange")
plt.show()

# %%
income.plot(kind="scatter", y="Income2005", x="AFQT")
x = np.linspace(income["AFQT"].min(), income["AFQT"].max())
b, a = np.polyfit(x=income["AFQT"], y=income["Income2005"], deg=1)
plt.plot(x, a+b*x, c="orange")
plt.show()

# %%
income.corr()
# Out:
#                 AFQT      Educ  Income2005
# AFQT        1.000000  0.595160    0.308153
# Educ        0.595160  1.000000    0.345647
# Income2005  0.308153  0.345647    1.000000

# %% [markdown]
# Diese Daten haben keine grosse korrelation - Lineares Modell nicht angebracht.

# %% [markdown]
# # Aufgabe 2.6

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y1 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])
y2 = np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])
y3 = np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])
x4 = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])
y4 = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89])

plt.subplot(2,2,1)
lin = np.linspace(x.min(), x.max())
b, a = np.polyfit(x=x, y=y1, deg=1)
print(a, " | ", b)
plt.plot(lin, a+b*lin, c="orange")
plt.scatter(x, y1)

plt.subplot(2,2,2)
lin = np.linspace(x.min(), x.max())
b, a = np.polyfit(x=x, y=y2, deg=1)
print(a, " | ", b)
plt.plot(lin, a+b*lin, c="orange")
plt.scatter(x, y2)

plt.subplot(2,2,3)
lin = np.linspace(x.min(), x.max())
b, a = np.polyfit(x=x, y=y3, deg=1)
print(a, " | ", b)
plt.plot(lin, a+b*lin, c="orange")
plt.scatter(x, y3)

plt.subplot(2,2,4)
lin = np.linspace(x4.min(), x4.max())
b, a = np.polyfit(x=x4, y=y4, deg=1)
print(a, " | ", b)
plt.plot(lin, a+b*lin, c="orange")
plt.scatter(x4, y4)


print(np.corrcoef(x, y1))
print(np.corrcoef(x, y2))
print(np.corrcoef(x, y3))
print(np.corrcoef(x4, y4))
# Out:
# 3.0000909090909076  |  0.5000909090909095
# 3.000909090909089  |  0.5000000000000004
# 3.0024545454545453  |  0.4997272727272731
# 3.0017272727272735  |  0.49990909090909064
# [[1.         0.81642052]
#  [0.81642052 1.        ]]
# [[1.         0.81623651]
#  [0.81623651 1.        ]]
# [[1.         0.81628674]
#  [0.81628674 1.        ]]
# [[1.         0.81652144]
#  [0.81652144 1.        ]]

# %% [markdown]
# Nur beim ersten Plot scheint eine Lineare Regression Sinn zu machen
# Es genügt also nicht, bloss a und b anzuschauen (Beta0 und Beta1)

# %% [markdown]
# # Aufgabe 2.7

# %%
from pandas import Series,DataFrame
import pandas as pd
data = pd.read_csv("child.csv", sep=",", index_col=0)
print(data)
data.describe()
# Out:
#                  Average.disposable.income  Children.in.poor.homes  \
# Australia                        20.813221               11.791352
# Austria                          22.162446                6.166094
# Belgium                          21.401153                9.974720
# Canada                           25.606245               15.057585
# Czech Republic                   10.849270               10.270000
# Denmark                          23.175894                2.740000
# Finland                          22.027651                4.170000
# France                           18.960382                7.640000
# Germany                          19.894067               16.289270
# Greece                           17.183647               13.230296
# Hungary                           9.463130                8.724203
# Iceland                          22.286852                8.250000
# Ireland                          22.364689               16.299416
# ...

# %%
data.dropna()
# Out:
#                 Average.disposable.income  Children.in.poor.homes  \
# Austria                         22.162446                6.166094
# Belgium                         21.401153                9.974720
# Czech Republic                  10.849270               10.270000
# Denmark                         23.175894                2.740000
# Finland                         22.027651                4.170000
# France                          18.960382                7.640000
# Germany                         19.894067               16.289270
# Greece                          17.183647               13.230296
# Hungary                          9.463130                8.724203
# Ireland                         22.364689               16.299416
# Italy                           17.180761               15.500000
# Netherlands                     25.041012               11.526755
# Norway                          28.574371                4.600000
# ...

# %%
data.dropna(axis=1, thresh=28)
# Müssen 28 gültige Werte vorhanden sein
# Out:
#                  Average.disposable.income  Children.in.poor.homes  \
# Australia                        20.813221               11.791352
# Austria                          22.162446                6.166094
# Belgium                          21.401153                9.974720
# Canada                           25.606245               15.057585
# Czech Republic                   10.849270               10.270000
# Denmark                          23.175894                2.740000
# Finland                          22.027651                4.170000
# France                           18.960382                7.640000
# Germany                          19.894067               16.289270
# Greece                           17.183647               13.230296
# Hungary                           9.463130                8.724203
# Iceland                          22.286852                8.250000
# Ireland                          22.364689               16.299416
# ...

# %%
# !pip install fancyimpute

# %%
from fancyimpute import KNN
values = data.values
data_imputed = DataFrame(KNN(k=3).fit_transform(values))
print(data.values)
print(data_imputed)
# Out:
# Imputing row 1/30 with 5 missing, elapsed time: 0.001
# [[2.08132209e+01 1.17913522e+01 2.20000000e+00 1.97000000e+01
#   1.05000000e+01 5.20000000e+02 1.61034921e+00 7.40000000e+00
#   6.40000000e+00 5.00000000e+00 9.20000000e+01 9.22000000e+01
#   9.40000000e+01            nan 2.36600000e+01 8.51264608e+00
#              nan            nan 1.43000000e+01            nan
#              nan]
#  [2.21624464e+01 6.16609438e+00 6.00000000e-01 3.40146005e+01
#   2.01541861e+01 5.02000000e+02 1.71694185e+00 6.90000000e+00
#   6.80000000e+00 4.20000000e+00 9.60000000e+01 8.30000000e+01
#   7.40000000e+01 1.96000000e+01 2.45700000e+01 9.48276105e+00
#   2.71000000e+01 1.86000000e+01 1.23000000e+01 1.56000000e+01
#   3.81000000e+01]
#  [2.14011526e+01 9.97472000e+00 1.00000000e+00 1.26145048e+01
#   2.97545264e+01 5.10330000e+02 1.74025774e+00 6.20000000e+00
#   7.80000000e+00 3.70000000e+00 7.15000000e+01 9.70000000e+01
#   8.80000000e+01 1.91000000e+01 2.89700000e+01 8.97771318e+00
# ...
