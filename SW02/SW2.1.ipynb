# %%
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt


data = Series([4.2, 2.3, 5.6, 4.5, 4.8, 3.9, 5.9, 2.4, 5.9, 6, 4, 3.7, 5, 5.2, 4.5, 3.6, 5, 6, 2.8, 3.3, 5.5, 4.2, 4.9, 5.1])

# %%
data.sort_values()

print(data.mean())
print(data.median())
data2 = data.copy()
data2.iloc[1] = -1213
data2.iloc[7] = -1223
data2.iloc[18] = -1123
# nach bearbeiten
print(data2.mean())
print(data2.median())
# Out:
# 4.5125
# 4.65
# -144.09166666666667
# 4.65

# %%
plt.subplot(2,2,1)
data.plot(kind="hist",ax=ax,edgecolor="black")
plt.subplot(2,2,2)
data2.plot(kind="hist", ax=ax, edgecolor="green")
plt.title("Histogramm von Methode A")
plt.xlabel("methodeA")
plt.ylabel("Haeufigkeit")
plt.show()

# %%
data2.plot(kind="hist", edgecolor="black")
plt.title("Histogramm von data")
plt.xlabel("data")
plt.ylabel("Haeufigkeit")
plt.show()
